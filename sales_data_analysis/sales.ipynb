# %%
import pandas as pd

# %%
df=pd.read_csv("./Sales_Data/Sales_April_2019.csv")

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
import os
data_files=[file for file in os.listdir('./Sales_Data')]

# %%
data_files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
merged_data=pd.DataFrame()

# %%
for name in data_files:
    dat=pd.read_csv("./Sales_Data/"+name)
    merged_data=pd.concat([merged_data,dat])

# %%
merged_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
merged_data.to_csv("merged_data.csv",index=False)

# %% [markdown]
# # data cleaning

# %%
nan_datas=merged_data[merged_data.isna().any(axis=1)]
nan_datas
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1          NaN     NaN              NaN        NaN        NaN              NaN
# 356        NaN     NaN              NaN        NaN        NaN              NaN
# 735        NaN     NaN              NaN        NaN        NaN              NaN
# 1433       NaN     NaN              NaN        NaN        NaN              NaN
# 1553       NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 10012      NaN     NaN              NaN        NaN        NaN              NaN
# 10274      NaN     NaN              NaN        NaN        NaN              NaN
# 10878      NaN     NaN              NaN        NaN        NaN              NaN
# 11384      NaN     NaN              NaN        NaN        NaN              NaN
# 11662      NaN     NaN              NaN        NaN        NaN              NaN
#
# [545 rows x 6 columns]

# %%
merged_data=merged_data.dropna(axis=0,how="all")

# %% [markdown]
# # Augment properties

# %% [markdown]
# ### add month column

# %%
merged_data['Month']=merged_data['Order Date'].str[:2]
merged_data =merged_data[merged_data['Month'].str[:2]!='Or']
# Out:
# <ipython-input-12-638436acc0e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['Month']=merged_data['Order Date'].str[:2]

# %%
merged_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# ...

# %%
merged_data['Month']=merged_data['Month'].astype('int32')

# %% [markdown]
# ##### add sales column

# %%
merged_data['Price Each']=merged_data['Price Each'].astype('float')

# %%
merged_data['Quantity Ordered']=merged_data['Quantity Ordered'].astype('int32')

# %%
merged_data['sales']=merged_data['Price Each']*merged_data['Quantity Ordered']

# %%
merged_data.groupby('Month').sum()
# Out:
#        Quantity Ordered    Price Each         sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %% [markdown]
# ## Add city

# %%
def getCity(x):
    s=x.split(',')
    res=s[1]+' '
    z=s[2].split()
    res+=z[0]
    return res
merged_data['City']=merged_data['Purchase Address'].apply(lambda x: getCity(x))

# %%
merged_data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  Month   sales  \
# ...

# %% [markdown]
# # find best month

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
months=range(1,13)
plt.xticks(months)
plt.bar(months,merged_data.groupby('Month').sum()['sales'])
 
plt.show()

# %% [markdown]
# # Best city

# %%
sorted(merged_data['City'].unique())
# Out:
# [' Atlanta GA',
#  ' Austin TX',
#  ' Boston MA',
#  ' Dallas TX',
#  ' Los Angeles CA',
#  ' New York City NY',
#  ' Portland ME',
#  ' Portland OR',
#  ' San Francisco CA',
#  ' Seattle WA']

# %%
merged_data.groupby('City').sum()
# Out:
#                    Quantity Ordered    Price Each   Month         sales
# City
#  Atlanta GA                   16602  2.779908e+06  104794  2.795499e+06
#  Austin TX                    11153  1.809874e+06   69829  1.819582e+06
#  Boston MA                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas TX                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles CA               33289  5.421435e+06  208325  5.452571e+06
#  New York City NY             27932  4.635371e+06  175741  4.664317e+06
#  Portland ME                   2750  4.471893e+05   17144  4.497583e+05
#  Portland OR                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco CA             50239  8.211462e+06  315520  8.262204e+06
#  Seattle WA                   16553  2.733296e+06  104941  2.747755e+06

# %%
cities=sorted(merged_data['City'].unique())
yData=merged_data.groupby('City').sum()['sales']
 
plt.bar(cities,yData)
plt.xlabel=('City')
plt.xticks(cities, rotation="vertical")
plt.ylabel=("Sales in million dollars")
plt.title=("City vs Sales bar chart")
plt.show()

# %% [markdown]
# ## Best time for advertising to attract maximum buyer

# %%
merged_data['Order Date']=pd.to_datetime(merged_data['Order Date'])

# %%
merged_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               City
# 0        Dallas TX
# 2        Boston MA
# 3   Los Angeles CA
# ...

# %%
merged_data['Hours']=merged_data['Order Date'].dt.hour

# %%
merged_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               City  Hours
# 0        Dallas TX      8
# 2        Boston MA     22
# ...

# %%
merged_data.groupby('Hours').sum()
# Out:
#        Quantity Ordered  Price Each  Month       sales
# Hours
# 0                  4428   709296.70  27554   713721.27
# 1                  2619   458490.00  16657   460866.88
# 2                  1398   233833.64   8507   234851.44
# 3                   928   144726.42   5904   145757.89
# 4                   937   162058.18   6148   162661.01
# 5                  1493   229621.21   9301   230679.82
# 6                  2810   445000.11  17539   448113.00
# 7                  4556   740568.11  28850   744854.12
# 8                  7002  1185970.62  43626  1192348.97
# 9                  9816  1628498.49  60981  1639030.58
# 10                12308  1932665.62  76928  1944286.77
# 11                14005  2288855.18  87654  2300610.24
# 12                14202  2299876.68  89161  2316821.34
# 13                13685  2139743.86  85808  2155389.80
# 14                12362  2072194.77  77836  2083672.73
# 15                11391  1931174.99  72060  1941549.60
# ...

# %%
hours= range(24)
yData=merged_data.groupby('Hours').sum()['sales']
 
plt.plot(hours,yData)
plt.xlabel="City"
plt.xticks(hours, rotation="vertical")
 
plt.show()

# %% [markdown]
# # most sold products

# %%
merged_data.groupby('Product').sum()
# Out:
#                             Quantity Ordered  Price Each   Month       sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
import numpy as np
productList= sorted(merged_data['Product'].unique())
plt.xticks(np.arange(19), productList ,rotation="vertical")
saleCount=merged_data.groupby('Product').sum()['Quantity Ordered']

plt.bar(productList,saleCount)
# Out:
# <BarContainer object of 19 artists>

# %% [markdown]
# ##  mostly sold together products

# %%
df=merged_data[merged_data['Order ID'].duplicated(keep=False)]
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 18      176574                Google Phone                 1      600.00
# 19      176574        USB-C Charging Cable                 1       11.95
# 30      176585  Bose SoundSport Headphones                 1       99.99
# ...        ...                         ...               ...         ...
# 11628   259303       AA Batteries (4-pack)                 1        3.84
# 11639   259314            Wired Headphones                 1       11.99
# 11640   259314      AAA Batteries (4-pack)                 2        2.99
# 11677   259350                Google Phone                 1      600.00
# 11678   259350        USB-C Charging Cable                 1       11.95
#
#                Order Date                       Purchase Address  Month  \
# ...

# %%
df['grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df.head()
# Out:
# <ipython-input-52-031cfb445aa7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  Month   sales  \
# ...

# %%
df=df[['Order ID','grouped']].drop_duplicates()

# %%
df.head()
# Out:
#     Order ID                                            grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter
